# %%
from dataset import NaiveVideoDataset
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# 2023-05-08 11:50:13.743255: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-05-08 11:50:14.247568: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
d = NaiveVideoDataset()
# Out:
# 5553it [00:25, 274.19it/s, filename=015-nm-01-180.avi.txt]
